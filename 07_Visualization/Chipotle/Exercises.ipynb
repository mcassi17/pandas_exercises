# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import collections
import matplotlib.pyplot as plt 

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.iloc[:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
df = chipo['item_name'].value_counts().to_frame()
df.columns
# Out:
# Index(['item_name'], dtype='object')

# %%
df_small = df[:5]
df_small['item_name'].plot(kind='bar')

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-428421665074> in <module>()
# ----> 1 chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype('float')
#       2 chipo['quant_price'] = chipo['item_price'] * chipo['quantity']
#       3 df1 = chipo.groupby('order_id')['quant_price'].sum()
#       4 df1
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2964         if (name in self._internal_names_set or name in self._metadata or
#    2965                 name in self._accessors):
# -> 2966             return object.__getattribute__(self, name)
#    2967         else:
#    2968             if name in self._info_axis:
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in __get__(self, instance, owner)
#     241             # this ensures that Series.str.<method> is well defined
# ...

# %%
chipo['quant_price'] = chipo['item_price'] * chipo['quantity']
df1 = chipo.groupby('order_id')['quantity','quant_price'].sum()
df1
# Out:
#           quantity  quant_price
# order_id
# 1                4        11.56
# 2                2        33.96
# 3                2        12.67
# 4                2        21.00
# 5                2        13.70
# 6                2        17.50
# 7                2        15.70
# 8                2        10.88
# 9                3        12.85
# 10               2        13.20
# 11               2        12.38
# 12               2        14.37
# 13               2        10.88
# 14               2        10.08
# 15               2        10.88
# 16               2        10.68
# 17               2        10.08
# 18               4        24.90
# 19               2        13.90
# 20               4        36.20
# 21               3        23.36
# 22               2        12.98
# 23               3        13.35
# 24               2        12.07
# 25               2        11.38
# 26               2        20.50
# 27               2        13.90
# 28               4        33.70
# ...

# %%
df1.plot(x='quant_price', y='quantity', kind='scatter', alpha=0.3)

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.
